# %% [markdown]
# # Section 2: Introduction to Fraud Detection
# ### Lecture 3: What is Anomaly Detection

# %% [markdown]
# ![image.png](attachment:d34cd146-4d56-4a5f-a06f-6d86b1ccac33.png)

# %% [markdown]
# - An anomaly can be seen as data that deviates substantially from the norm
# - Anomaly detection is the process of identifying rare observations which differ substantially from the majority of the data from where they are drawn
# - Applications include intrusion detection, fraud detection, fault detection, healthcare monitoring etc

# %% [markdown]
# negócios financeiros, transações

# %% [markdown]
# # Example
# - Assuming a single array/list of data contains a distribution of IQ scores within a given population

# %% [markdown]
# histograma para ver a normal distribuição, com uma média de 100, desvio padrão de 10.
#
# População
#
# mu média
#
# sigma desvio

# %%
import numpy as np

# %%
mu, sigma = 100, 10
s = np.random.normal(mu, sigma, 1000)  
# criar uma distribuição dos dados normais, com média de 100 e desvio padrão de 10, com 1000 dados

# %%
# limite de 70 a 130

# %%
import matplotlib.pyplot as plt
plt.hist(s, 40) # amostra sample = s e  bin de 40
plt.show()

# %% [markdown]
# # Boxplot
# - "Minimum": 25th percentile - (1.5 * IQR)
# - IQR: range from 25th to 75th percentile
# - Median
# - "Maximum": 75th percentile + (1.5 * IQR)
# - Outliers falls above "maximum" or below "minimum"

# %%
plt.boxplot(s)
plt.show()

# %% [markdown]
# - While these techniques work for 1d data i.e. single columns, the higher-dimensional case is too complicated for these approaches.
# - A non-linear approach is therefore required, as we need to determine how the data from different columns in the feature space interacts with each other, adding to the predictive ability of the approach.

# %% [markdown]
# outlier fora do gráfico do desvio padrão
