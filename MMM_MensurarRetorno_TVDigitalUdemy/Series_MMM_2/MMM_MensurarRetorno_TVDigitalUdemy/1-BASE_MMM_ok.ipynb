# %% [markdown]
# # 1.2) Marketing Mix Modeling (MMM)
#
# Modelo estatístico

# %% [markdown]
# - Resultados através das ações publicitárias.
#
#
#
# - TV + Google Adwords (anuncios no google) + Email + ... + events
#
#
# - #### Retorno sobre o investimento => ROI => Return on investment (ROI)
#
# ROI: O que você gerou de resultados, positivos ou negativos, com base no que você investiu em publicidade.
#
# ROI termo da área de finanças.
#
# ROI: Todo o gasto ou investimento efetuados a vendas, e vemos se os resultados são positivos ou negativos.
#
# Fórmula básica é: ROI = (Lucro Líquido / Custo do Investimento) * 100.

# %% [markdown]
# ![image.png](attachment:03a17352-8696-4cc8-b179-d70d12c29972.png)

# %% [markdown]
# Ação intermediária, campanha publicitária para levar as pessoas para o meu site. Chamando de leads, pegando cadastros de uma pessoa, e o marketing chama de ROI.
#
# No Marketing conhecido como ROIM.

# %% [markdown]
# # 1.3) Quais as variáveis que podem ser colocadas no modelo Marketing Mix Modeling (MMM).
#
# Mídias para investir dinheiro, para fazer publicidade e anunciar um produto, ou a marca da empresa.
#
#
# ### Mídia off line: OOH (Out of Home), Radio, Open TV, pay TV (TV paga), magazine. Pessoa que é impactada não tem uma ação direta - interação.
#
#
# ##### Out of Home :Banner do outdoor, cartaz no ponto de ônibus, bus door
#
#
# ### Mídia on line: Portal (vertical) (portais do uol, g1,), e-mail MKT, Social Media, Adwords (anúncios no google),progamas afiliados
#
# => variáveis independentes, para ver os resultados do retorno – ROI.
#
#
# Diferenças da mídia.
#
# ### Events and experience: Feiras e exposições, eventos dentro do facebook, equipe esportivas e eventos.
#
#
#
# Quantidades de Variáveis podem ter mais ou menos precisão. Modelo pode ter erro.
#
# Depende de situações e do tipo de produto. Dependendo da quantidade, maior ou menor de variáveis. Não existe uma receita. Dependendo uso grupos e variáveis diferentes.

# %% [markdown]
# # 1.4) Marketing Mix Modeling (MMM): equação, modelo estatístico.
#
# Modelo estatístico que utiliza como variável as ações publicitárias. Não é só investimento à mídia. Empresa ação social, eventos, saiu matéria boa ação.
#
# Definir qualitativamente o impacto de uma empresa.
#
# Não dá para prever o que vai vender no futuro.
#
# Investimento e previsão do que a empresa vai ter de retorno ROI.
#
# Focados em investimentos monetários.

# %% [markdown]
# # 1.5) Modelo de atribuição vx Markeing Mix Modeling
#
# - Jornada do consumidor.
#
# Problema é tentar identificar qual é a jornada do consumidor que efetivamente faz com que ele compre o produto. Impactação do público, por várias vezes, google, facebook, rádio, tv.
#
# Cadeia de Markov, modelo de atribuição => processos estocásticos. Ver a melhor jornada do consumidor que maximiza a sua receita.
#
#
# - MMM fala com base no que você gerou de resultado. Novos resultados com base numa determinada ação num conjunto de ações. MMM meta de campanha.
#
# ![image.png](attachment:0ffcc0ac-6d9b-4690-9329-e482bbb177dd.png)

# %% [markdown]
# # 1.7) Maximizar ROI com MMM e jornada do consumidor
#
# Como utilizar as duas ferramentas para maximizar o retorno sobre o investimento.
#
# * modelo atribuição - determinar a jornada do consumidor.
#
# nós temos condições de com base nas características apresentadas
#
# para maximizar o retorno pelo investimento.
#
# Precisamos identificar qual a melhor equação, e analisar o erro. Definir a melhor estratégia, além de usar a mecânica.
#
#
# * Marketing Mix Modeling(MMM) objetivo de determinar qual é o controle esperado, prever o que vai acontecer. Com base nas ações que você já tomoou e que você quer tomar. Por exemplo, investimento publicitário.
#
# Investimento será doprado no próximo mês, e queremos saber como será os próximos meses.
#
# ** anúncio em mídias que não geram retorno, transfiro o investimento para mídias que geram mais retorno.
